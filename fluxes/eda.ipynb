# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(17):
    data = np.load(f'../examples/PyMPDATA_examples/Arabas_and_Farhat_2020/data/advectee_{i}.npy')
    plt.plot(data, alpha=1*i/17, color='b')
plt.xlabel('x')
plt.ylabel('advectee')
plt.title('advectee evolution over time')
plt.show()

# %%
for i in range(10,11):
    data = np.load(f'../examples/PyMPDATA_examples/Arabas_and_Farhat_2020/data/advector_{i}.npy')
    plt.plot(data, alpha=1*i/17, color='b')
    
plt.xlabel('x')
plt.ylabel('advector')
plt.title('advector evolution over time')
plt.show()

# %%
for i in range(17):
    data = np.load(f'../examples/PyMPDATA_examples/Arabas_and_Farhat_2020/data/corrective_flux_{i}.npy')
    plt.plot(data, alpha=1*i/17, color='b')
plt.show()
